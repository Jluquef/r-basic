# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]

# %%
plt.plot (x)
plt.xlabel ("Eje de abcisas")
plt.ylabel ("Eje de ordenada")
# Out:
# Text(0, 0.5, 'Eje de ordenada')

# %%
x = [1,2,3,4]
y = [2,4,9,16]
plt.plot (x,y)

# %%
plt.plot (x,y,"ro")
plt.axis ([0,6,0,20])
plt.show ()

# %%
import numpy as np

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a02d25306752> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined
