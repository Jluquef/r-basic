# %%
import math

# %%
3*5
# Out:
# 15

# %% [markdown]
# # integral

# %% [markdown]
# $\int_0^1 x^2 dx$

# %%
$\int_0^1 x^2 dx$
# Out:
#   File "<ipython-input-3-5296ea0082af>", line 1
#     $\int_0^1 x^2 dx$
#     ^
# SyntaxError: invalid syntax

# %%
7**4
# Out:
# 2401

# %%
5**5
# Out:
# 3125

# %%
4**6
# Out:
# 4096

# %%
5**6
# Out:
# 15625

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
math.pow(5,5)
# Out:
# 3125.0
